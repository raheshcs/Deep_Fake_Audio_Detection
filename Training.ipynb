# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import librosa
import os
import math
import shutil
import pandas as pd
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
BASE_PATH = '/kaggle/input/asvpoof-2019-dataset/LA/LA'

# %%
train_df = pd.read_csv(f'{BASE_PATH}/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.train.trn.txt',
                       sep=" ", header=None)

# %%
train_df.head(5)
# Out:
#          0             1  2  3         4
# 0  LA_0079  LA_T_1138215  -  -  bonafide
# 1  LA_0079  LA_T_1271820  -  -  bonafide
# 2  LA_0079  LA_T_1272637  -  -  bonafide
# 3  LA_0079  LA_T_1276960  -  -  bonafide
# 4  LA_0079  LA_T_1341447  -  -  bonafide

# %%
train_df.columns =['speaker_id','filename','system_id','null','class_name']
train_df.drop(columns=['null'],inplace=True)
train_df.head(5)
# Out:
#   speaker_id      filename system_id class_name
# 0    LA_0079  LA_T_1138215         -   bonafide
# 1    LA_0079  LA_T_1271820         -   bonafide
# 2    LA_0079  LA_T_1272637         -   bonafide
# 3    LA_0079  LA_T_1276960         -   bonafide
# 4    LA_0079  LA_T_1341447         -   bonafide

# %%
train_df['filepath'] = f'{BASE_PATH}/ASVspoof2019_LA_train/flac/'+train_df.filename+'.flac'
train_df['target'] = (train_df.class_name=='spoof').astype('int32')
print('len Train', len(train_df))
train_df.head(5)
# Out:
# len Train 25380
#   speaker_id      filename system_id class_name  \
# 0    LA_0079  LA_T_1138215         -   bonafide
# 1    LA_0079  LA_T_1271820         -   bonafide
# 2    LA_0079  LA_T_1272637         -   bonafide
# 3    LA_0079  LA_T_1276960         -   bonafide
# 4    LA_0079  LA_T_1341447         -   bonafide
#
#                                             filepath  target
# 0  /kaggle/input/asvpoof-2019-dataset/LA/LA/ASVsp...       0
# 1  /kaggle/input/asvpoof-2019-dataset/LA/LA/ASVsp...       0
# 2  /kaggle/input/asvpoof-2019-dataset/LA/LA/ASVsp...       0
# 3  /kaggle/input/asvpoof-2019-dataset/LA/LA/ASVsp...       0
# 4  /kaggle/input/asvpoof-2019-dataset/LA/LA/ASVsp...       0

# %%
import os
import shutil

# Check previously created folders and create if necessary
output_folder_0 = './0'  # Klasör adı 0
output_folder_1 = './1'  # Klasör adı 1

if not os.path.exists(output_folder_0):
    os.makedirs(output_folder_0)

if not os.path.exists(output_folder_1):
    os.makedirs(output_folder_1)

# Return the Train data frame and copy the files to the relevant folders
for index, row in train_df.iterrows():
    source_filepath = row['filepath']
    target_folder = f'./{row["target"]}'
    target_filepath = os.path.join(target_folder, os.path.basename(source_filepath))

    # Check the target folder and create it if necessary
    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    # Copy file to destination folder
    shutil.copy(source_filepath, target_filepath)

# Once the process is complete you can use it to check the created folders
print(f'There are  {len(os.listdir(output_folder_0))} in folder 0.')
print(f'There are {len(os.listdir(output_folder_1))} in folder 1.')
# Out:
# There are  2580 in folder 0.
# There are 22800 in folder 1.

# %%
folder_path = './0' 

files = os.listdir(folder_path)

total_files = len(files)

print(f"Klasörde toplam {total_files} dosya var.")
# Out:
# Klasörde toplam 2580 dosya var.

# %%
import os


folder_path = './1'  # Değiştirmeniz gereken klasör yolu

files = os.listdir(folder_path)

total_files = len(files)

print(f"Klasörde toplam {total_files} dosya var.")
# Out:
# Klasörde toplam 22800 dosya var.

# %%
import random

folder_path = './0'  # The folder path you need to change

files = os.listdir(folder_path)

total_files = len(files)

# Number of files to delete
num_files_to_delete = 1580

files_to_delete = random.sample(files, min(num_files_to_delete, total_files))

for file_name in files_to_delete:
    file_path = os.path.join(folder_path, file_name)
    try:
        os.remove(file_path)
#         print(f"{file_name} file has been deleted..")
    except Exception as e:
        print(f"Error while clearing: {e}")

remaining_files = os.listdir(folder_path)
# print(f"There are a total of  {len(remaining_files)} files remaining in the folder.")

# %%
import random

folder_path = './1' 

files = os.listdir(folder_path)

total_files = len(files)

# Number of files to delete
num_files_to_delete = 21800

files_to_delete = random.sample(files, min(num_files_to_delete, total_files))

for file_name in files_to_delete:
    file_path = os.path.join(folder_path, file_name)
    os.remove(file_path)

# %%
import os
import shutil

source_folders = ['0', '1']

# Name of destination folder
target_folder = 'audio'

if not os.path.exists(target_folder):
    os.makedirs(target_folder)

for source_folder in source_folders:
    source_folder_path = os.path.join('.', source_folder)
    target_folder_path = os.path.join(target_folder, source_folder)

    # Check if there is a resource folder
    if os.path.exists(source_folder_path):
        # Hedef klasörü oluştur
        if not os.path.exists(target_folder_path):
            os.makedirs(target_folder_path)

        # Move files in source folder to target folder
        for file_name in os.listdir(source_folder_path):
            source_file_path = os.path.join(source_folder_path, file_name)
            target_file_path = os.path.join(target_folder_path, file_name)
            shutil.move(source_file_path, target_file_path)

# print(f"Process completed. . '{target_folder}'folder contains the following files::")
# print(os.listdir(target_folder))

# %%
DATASET_PATH = "/kaggle/working/audio"
JSON_PATH = "data.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION

# %%
def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):

    
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        
        if dirpath is not dataset_path:

            
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            
            for f in filenames:

                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                
                for d in range(num_segments):

                    
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # mfcc çıkar
                    mfcc = librosa.feature.mfcc(y=signal[start:finish], sr=sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                    mfcc = mfcc.T

                    
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)

    #  MFCCs leri json olarak kaydet
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
if __name__ == "__main__":
    save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=0
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=174
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1210
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1971
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=984
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1831
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1201
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=39
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1760
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=455
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=921
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1381
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1357
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1339
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1454
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=680
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=917
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1230
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1687
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=559
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=662
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=357
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1541
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=765
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1205
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1894
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=187
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1744
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=480
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=413
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1120
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1897
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=655
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1476
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=946
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=593
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1985
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1813
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1049
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=582
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=469
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1464
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1347
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1566
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1492
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1510
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=552
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=535
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1394
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=669
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=517
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1485
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1505
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=618
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1139
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1570
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1489
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=637
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1501
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=567
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1529
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=534
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1515
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=526
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1419
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1583
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1465
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=575
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=290
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1474
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1591
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=477
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=570
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=523
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=568
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1395
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=583
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=604
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=505
#   warnings.warn(

# %%
DATA_PATH = "/kaggle/working/data.json"


def load_data(data_path):

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y

def prepare_datasets(test_size, validation_size):

    
    X, y = load_data(DATA_PATH)

    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):

    
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(2, activation='softmax'))

    return model


def predict(model, X, y):

    
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    
    prediction = model.predict(X)

    
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))

# %%
if __name__ == "__main__":

    
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    
    
    input_shape = (130, 13, 1)
    model = build_model(input_shape)

    
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    early_stopping = keras.callbacks.EarlyStopping(
            monitor='val_loss', 
            verbose=1,
            patience=5,
            mode='min',
            restore_best_weights=True,
        )
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=50,callbacks=[early_stopping],
)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 128, 11, 32)       320
#
#  max_pooling2d_6 (MaxPoolin  (None, 64, 6, 32)         0
#  g2D)
#
#  batch_normalization_6 (Bat  (None, 64, 6, 32)         128
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 62, 4, 32)         9248
#
#  max_pooling2d_7 (MaxPoolin  (None, 31, 2, 32)         0
#  g2D)
#
#  batch_normalization_7 (Bat  (None, 31, 2, 32)         128
#  chNormalization)
#
#  conv2d_8 (Conv2D)           (None, 30, 1, 32)         4128
#
#  max_pooling2d_8 (MaxPoolin  (None, 15, 1, 32)         0
#  g2D)
#
#  batch_normalization_8 (Bat  (None, 15, 1, 32)         128
#  chNormalization)
#
#  flatten_2 (Flatten)         (None, 480)               0
#
#  dense_4 (Dense)             (None, 64)                30784
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 44994 (175.76 KB)
# Trainable params: 44802 (175.01 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 24/24 [==============================] - 4s 18ms/step - loss: 0.8034 - accuracy: 0.6115 - val_loss: 0.7758 - val_accuracy: 0.5990
# Epoch 2/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.5812 - accuracy: 0.7327 - val_loss: 0.7807 - val_accuracy: 0.5938
# Epoch 3/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4981 - accuracy: 0.7757 - val_loss: 0.6950 - val_accuracy: 0.5833
# Epoch 4/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.4257 - accuracy: 0.8083 - val_loss: 0.6219 - val_accuracy: 0.6250
# Epoch 5/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.3463 - accuracy: 0.8605 - val_loss: 0.5434 - val_accuracy: 0.7083
# Epoch 6/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.3320 - accuracy: 0.8644 - val_loss: 0.4792 - val_accuracy: 0.7865
# Epoch 7/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2894 - accuracy: 0.8814 - val_loss: 0.4359 - val_accuracy: 0.8073
# Epoch 8/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2775 - accuracy: 0.8931 - val_loss: 0.4261 - val_accuracy: 0.8021
# Epoch 9/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2426 - accuracy: 0.8970 - val_loss: 0.3965 - val_accuracy: 0.8125
# Epoch 10/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.2401 - accuracy: 0.9074 - val_loss: 0.3464 - val_accuracy: 0.8438
# Epoch 11/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2163 - accuracy: 0.9100 - val_loss: 0.3129 - val_accuracy: 0.8646
# Epoch 12/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2139 - accuracy: 0.9113 - val_loss: 0.3047 - val_accuracy: 0.8646
# Epoch 13/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1895 - accuracy: 0.9270 - val_loss: 0.2796 - val_accuracy: 0.8750
# Epoch 14/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1705 - accuracy: 0.9413 - val_loss: 0.2691 - val_accuracy: 0.8698
# Epoch 15/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1740 - accuracy: 0.9426 - val_loss: 0.2475 - val_accuracy: 0.8750
# Epoch 16/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1398 - accuracy: 0.9583 - val_loss: 0.2577 - val_accuracy: 0.8854
# Epoch 17/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1667 - accuracy: 0.9426 - val_loss: 0.2382 - val_accuracy: 0.8750
# Epoch 18/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1423 - accuracy: 0.9492 - val_loss: 0.2411 - val_accuracy: 0.8698
# Epoch 19/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1204 - accuracy: 0.9648 - val_loss: 0.2210 - val_accuracy: 0.8958
# Epoch 20/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1190 - accuracy: 0.9622 - val_loss: 0.2235 - val_accuracy: 0.8958
# Epoch 21/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1184 - accuracy: 0.9570 - val_loss: 0.2308 - val_accuracy: 0.8854
# Epoch 22/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1245 - accuracy: 0.9557 - val_loss: 0.2148 - val_accuracy: 0.9010
# Epoch 23/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1042 - accuracy: 0.9752 - val_loss: 0.2054 - val_accuracy: 0.9115
# Epoch 24/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1039 - accuracy: 0.9713 - val_loss: 0.2017 - val_accuracy: 0.9062
# Epoch 25/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0922 - accuracy: 0.9700 - val_loss: 0.2049 - val_accuracy: 0.8906
# Epoch 26/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0842 - accuracy: 0.9778 - val_loss: 0.2024 - val_accuracy: 0.8906
# Epoch 27/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0962 - accuracy: 0.9700 - val_loss: 0.1965 - val_accuracy: 0.9167
# Epoch 28/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0781 - accuracy: 0.9844 - val_loss: 0.1933 - val_accuracy: 0.9219
# Epoch 29/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0742 - accuracy: 0.9765 - val_loss: 0.1905 - val_accuracy: 0.9167
# Epoch 30/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0782 - accuracy: 0.9817 - val_loss: 0.2075 - val_accuracy: 0.8906
# Epoch 31/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0769 - accuracy: 0.9778 - val_loss: 0.1914 - val_accuracy: 0.9062
# Epoch 32/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0759 - accuracy: 0.9739 - val_loss: 0.1831 - val_accuracy: 0.9167
# Epoch 33/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0617 - accuracy: 0.9857 - val_loss: 0.1828 - val_accuracy: 0.9219
# Epoch 34/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0513 - accuracy: 0.9922 - val_loss: 0.1855 - val_accuracy: 0.9062
# Epoch 35/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0638 - accuracy: 0.9831 - val_loss: 0.1812 - val_accuracy: 0.9167
# Epoch 36/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0520 - accuracy: 0.9896 - val_loss: 0.1837 - val_accuracy: 0.9167
# Epoch 37/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0510 - accuracy: 0.9870 - val_loss: 0.1857 - val_accuracy: 0.9219
# Epoch 38/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0643 - accuracy: 0.9831 - val_loss: 0.1866 - val_accuracy: 0.9271
# Epoch 39/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0428 - accuracy: 0.9948 - val_loss: 0.1797 - val_accuracy: 0.9271
# Epoch 40/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0462 - accuracy: 0.9909 - val_loss: 0.1770 - val_accuracy: 0.9323
# Epoch 41/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0355 - accuracy: 0.9961 - val_loss: 0.1766 - val_accuracy: 0.9167
# Epoch 42/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0403 - accuracy: 0.9909 - val_loss: 0.1819 - val_accuracy: 0.9323
# Epoch 43/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0413 - accuracy: 0.9896 - val_loss: 0.1692 - val_accuracy: 0.9323
# Epoch 44/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0365 - accuracy: 0.9935 - val_loss: 0.1716 - val_accuracy: 0.9323
# Epoch 45/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0351 - accuracy: 0.9922 - val_loss: 0.1683 - val_accuracy: 0.9271
# Epoch 46/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0332 - accuracy: 0.9948 - val_loss: 0.1696 - val_accuracy: 0.9167
# Epoch 47/50
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0314 - accuracy: 0.9961 - val_loss: 0.1648 - val_accuracy: 0.9271
# Epoch 48/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0282 - accuracy: 0.9974 - val_loss: 0.1676 - val_accuracy: 0.9219
# Epoch 49/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0305 - accuracy: 0.9961 - val_loss: 0.1717 - val_accuracy: 0.9375
# Epoch 50/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0332 - accuracy: 0.9909 - val_loss: 0.1793 - val_accuracy: 0.9271
# 10/10 - 0s - loss: 0.3045 - accuracy: 0.9031 - 46ms/epoch - 5ms/step
#
# Test accuracy: 0.903124988079071

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
from sklearn.metrics import classification_report

fig, axs = plt.subplots(1, 3, figsize=(15, 5))  # 1 row, 3 columns for accuracy, loss, and confusion matrix

# Plot accuracy
axs[0].plot(history.history["accuracy"], label="Train")
axs[0].plot(history.history["val_accuracy"], label="Test")
axs[0].set_ylabel("Accuracy",fontsize=14)
axs[0].set_xlabel("Number of Epochs",fontsize=14)
axs[0].legend(loc="lower right",fontsize=12)
axs[0].set_title("Model Accuracy", fontsize=16)

# Plot loss
axs[1].plot(history.history["loss"], label="Train")
axs[1].plot(history.history["val_loss"], label="Test")
axs[1].set_ylabel("Loss", fontsize=14)
axs[1].set_xlabel("Number of Epochs",fontsize=14)
axs[1].legend(loc="upper right", fontsize=12)
axs[1].set_title("Model Loss", fontsize=16)

# Plot confusion matrix
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
loss = model.evaluate(X_train, y_train)
cf_matrix = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cf_matrix, display_labels=['Fake', 'Real'])
disp.plot(ax=axs[2], cmap='Purples')
disp.ax_.set_title('Confusion Mtarix', fontsize=16, fontweight='medium')
disp.im_.colorbar.remove()
disp.ax_.set_xlabel('Predicted label', fontsize=14)
disp.ax_.set_ylabel('True label', fontsize=14)
disp.ax_.set_xticklabels(['Fake', 'Real'], fontsize=12)
disp.ax_.set_yticklabels(['Fake', 'Real'], fontsize=12)
plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()
# Out:
# 10/10 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.89       144
#            1       0.89      0.94      0.91       176
#
#     accuracy                           0.90       320
#    macro avg       0.91      0.90      0.90       320
# weighted avg       0.90      0.90      0.90       320
#
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 0.9987

# %%
# Modeli kaydet
model.save("/kaggle/working/cnn_audio.h5")
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow.keras.models import load_model
import tensorflow as tf

# %%
def predict_voice(model, audio_file_path, genre_mapping):

    
    signal, sample_rate = librosa.load(audio_file_path, sr=22050)

    
    mfcc = librosa.feature.mfcc(y=signal, sr=sample_rate, n_mfcc=13, n_fft=2048, hop_length=512)
    mfcc = mfcc.T

    # MFCC'leri uygun boyuta getir
    mfcc = np.resize(mfcc, (130, 13, 1))

    # Reshape MFCC'leri uygun boyuta gwtir
    mfcc = mfcc[np.newaxis, ...]

   
    prediction = model.predict(mfcc)
    predicted_index = np.argmax(prediction, axis=1)

    
    genre_label = genre_mapping[predicted_index[0]]
    print("Raw prediction:", prediction)

    return genre_label


model_path = "/kaggle/input/audio-for-lstm/cnn_audio.h5"
model = load_model(model_path)


audio_file_path = "/kaggle/input/asvpoof-2019-dataset/LA/LA/ASVspoof2019_LA_train/flac/LA_T_1130924.flac"
#/kaggle/input/audio-for-lstm/audio/0/LA_T_1130924.flac
#/kaggle/input/asvpoof-2019-dataset/LA/LA/ASVspoof2019_LA_train/flac/LA_T_1034356.flac

genre_mapping = {0: "spoof", 1: "bonafide"}


predicted_voice = predict_voice(model, audio_file_path, genre_mapping)

print("Predicted label:", predicted_voice)
# Out:
# 1/1 [==============================] - 0s 147ms/step
# Raw prediction: [[0.0675776 0.9324224]]
# Predicted label: bonafide
